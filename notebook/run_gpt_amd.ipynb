# %%
from openai import OpenAI
# Set OpenAI's API key and API base to use vLLM's API server.
openai_api_key = "EMPTY"
openai_api_base = "http://localhost:8000/v1"

client = OpenAI(
    api_key=openai_api_key,
    base_url=openai_api_base,
)

chat_response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is AMD Developer Cloud? in one sentence"},
    ]
)
print("Chat response:", chat_response)
# Out:
# Chat response: ChatCompletion(id='chatcmpl-05f17bdbf7e549ef88a0c5025cc51df2', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='analysisWe need to answer concisely in one sentence. Provide definition: AMD Developer Cloud is a free cloud-based platform providing access to AMD hardware (CPUs/GPUs) and development tools for building and testing software. One sentence.assistantfinalAMD Developer Cloud is a free, cloud‑based platform that gives developers on‑demand access to AMD CPUs, GPUs and associated software tools for building, testing, and optimizing applications.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[], reasoning_content=None), stop_reason=None)], created=1779715540, model='openai/gpt-oss-120b', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=94, prompt_tokens=89, total_tokens=183, completion_tokens_details=None, prompt_tokens_details=None), prompt_logprobs=None, kv_transfer_params=None)

# %%
raw_content = chat_response.choices[0].message.content

# %%
clean_content = raw_content.split("assistantfinal")[-1].strip()

# %%
print(clean_content)
# Out:
# AMD Developer Cloud is a free, cloud‑based platform that gives developers on‑demand access to AMD CPUs, GPUs and associated software tools for building, testing, and optimizing applications.
